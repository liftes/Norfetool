# %%
import norfetools as Dplt
from norfetools import plt
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl


# 创建示例数据
data = np.random.rand(10, 10)

# 创建热力图
fig, ax = plt.subplots()
cax = ax.imshow(data, cmap='viridis')

# 创建 colorbar
cbar = fig.colorbar(cax)

# 使用自定义函数设置 colorbar 刻度线朝内
Dplt.Set_colorbar_ticks_inward(cbar, )
# Dplt.Set_colorbar_ticks_outward(cbar, )

# 显示热力图
plt.show()


plt.figure(figsize=(3,3))
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16],label="test")  # 示例图表
plt.xlabel("test x $x=y$")
Dplt.Set_axis_formatting('both', nbins=6, decimals=0)  # 设置x轴和y轴
plt.legend()
Dplt.SaveFig(2, "test", )

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

data = np.random.rand(10, 20) * 2 - 1  # 在 [-1, 1] 范围内
cmap = plt.cm.coolwarm
fig, ax = plt.subplots(figsize=(4, 2))
img = ax.imshow(data, aspect='auto', cmap=cmap, origin='lower', vmin=-1, vmax=1)

# 添加顶部 colorbar
divider = make_axes_locatable(ax)
cax = divider.append_axes("top", size="10%", pad=0.3)
cbar = fig.colorbar(img, cax=cax, orientation='horizontal')
Dplt.Set_colorbar_ticks_outward(cbar)

# %%
plt.figure(figsize=(3,3))
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])  # 示例图表
Dplt.Set_axis_formatting('both', nbins=6, decimals=0)  # 设置x轴和y轴
Dplt.SaveFig(1, "test.png")

# %%
with Dplt.Set_style():
    plt.figure(figsize=(3,1))
    plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])  # 示例图表
    plt.xlabel(r"test x $R_{\text{g}} = Nb^2/6$")
    Dplt.Set_axis_formatting('both', nbins=6, decimals=3)  # 设置x轴和y轴
    Dplt.SaveFig(1, "test.png", )

# %%
plt.figure(figsize=(3,3))
plt.plot([0, 1, 2, 3, 4], [0, 1, 4, 9, 16],label="test")  # 示例图表
plt.xlabel("test x $x=y$")
Dplt.Set_axis_formatting('both', nbins=6, decimals=0)  # 设置x轴和y轴
plt.legend()
Dplt.SaveFig(0, "test.png", )

# %%
colors = Dplt.SetColor("Set2", 6)
Dplt.TestColorList(colors)

# %%
colors = Dplt.SetColor("tab10", 6, True)
Dplt.TestColorList(colors)

# %%
import numpy as np
data = np.array((20,20))
Dplt.Save_data(data, "Data/testdata.pkl")
data2 = Dplt.Load_data("Data/testdata.pkl")
